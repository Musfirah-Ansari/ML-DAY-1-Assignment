# %% [markdown]
# <a href="https://colab.research.google.com/github/Musfirah-Ansari/ML-DAY-1-Assignment/blob/main/MLDAY1Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### *Simple Banking System*
#
# > *Welcome to The "Simple Bank" - Your Personal Money Management System*

# %%
# ML DAY 1 Assignment By "MUSFIRAH FAYYAZ"

#Design and implement a simple banking system in Python that allows users to perform basic banking operations.
#The program should enable users to:

# 1. Create an account with their name and account number.
accountsDictionary = {}

def createNewAccount():
    print("\n*** Create a New Account ***\n")
    completeName = input("Enter Your Complete Name: ")
    yourAccountNumber = input("Select Your New Account Number: ")

    if yourAccountNumber in accountsDictionary:
        print("\n Uh-oh! The Provided Account Number Already Exists. Kindly Select a Unique One.")
        return

    password = input("Set a password for your account: ")
    accountsDictionary[yourAccountNumber] = {"completeName": completeName, "totalBalance": 0.0, "OverallTransactions": [], "password": password}
    print(f"\n🎉 The Account has now been created for {completeName} with Account # : {yourAccountNumber}.\n")

# 2. Deposit money into their account.
def depositMoneyInAcc():
    print("\n*** Deposit Money Into Your ACCOUNT ***")
    yourAccountNumber = input("Please Type Your Complete Account # Here: ")

    if yourAccountNumber not in accountsDictionary:
        print("\n🚫 The Provided Account NOT Found in Valid Accounts List! Please Try Again with the Correct one.\n")
        return

    try:
        totalAmount = float(input("Enter the amount you want to deposit in: $"))
        if totalAmount <= 0:
            print("\n❌ Invalid amount! Please enter a valid positive number.\n")
            return

        accountsDictionary[yourAccountNumber]["totalBalance"] += totalAmount
        accountsDictionary[yourAccountNumber]["OverallTransactions"].append(f"Deposited: +${totalAmount:.2f}")
        print(f"\n✅ The amount has been deposited successfully! ${totalAmount:.2f} has been added to your account.\n")
    except ValueError:
        print("\n⚠️ Oops! That wasn't a valid amount. Please enter a number.\n")

# 3. Withdraw money from their account, ensuring sufficient funds are available.
def withdraw_money():
    print("\n*** Withdraw Money ***")
    yourAccountNumber = input("Please Type Your Complete Account # Here: ")

    if yourAccountNumber not in accountsDictionary:
        print("\n🚫 The Provided Account NOT Found in Valid Accounts List! Please Try Again with the Correct one.\n")
        return

    try:
        totalAmount = float(input("Enter the amount to withdraw: $"))
        if totalAmount <= 0:
            print("\n❌ Invalid amount! Please enter a valid positive number.\n")
            return

        if accountsDictionary[yourAccountNumber]["totalBalance"] < totalAmount:
            print(f"\n⚠️ Insufficient funds! You have only ${accountsDictionary[yourAccountNumber]['totalBalance']:.2f} in your account.\n")
            return

        accountsDictionary[yourAccountNumber]["totalBalance"] -= totalAmount
        accountsDictionary[yourAccountNumber]["OverallTransactions"].append(f"Withdrew: -${totalAmount:.2f}")
        print(f"\n✅ Withdrawal successful! ${totalAmount:.2f} withdrawn from your account.\n")
    except ValueError:
        print("\n⚠️ Oops! That wasn't a valid amount. Please enter a number.\n")

# 4. Check their account balance.
def check_balance():
    print("\n*** Check Your Balance Here ***")
    yourAccountNumber = input("Please Type Your Complete Account # Here: ")

    if yourAccountNumber not in accountsDictionary:
        print("\n🚫 The Provided Account NOT Found in Valid Accounts List! Please Try Again with the Correct one.\n")
        return

    balance = accountsDictionary[yourAccountNumber]["totalBalance"]
    print(f"\nYour current balance is: ${balance:,.2f}\n")

# 5. View a transaction history of all deposits and withdrawals.
def view_transactions():
    print("\n*** View Your Transaction History ***")
    yourAccountNumber = input("Please Type Your Complete Account # Here: ")

    if yourAccountNumber not in accountsDictionary:
        print("\n🚫 The Provided Account NOT Found! Please Try Again with the Correct one.\n")
        return

    transactions = accountsDictionary[yourAccountNumber]["OverallTransactions"]
    if not transactions:
        print("\nNo transactions found for the provided account.\n")
    else:
        print("\nTransaction history:")
        for transaction in transactions:
            print(f"- {transaction}")
        print()

def change_password():
    print("\n*** Change Your Account Password ***")
    yourAccountNumber = input("Enter Your Account Number: ")

    if yourAccountNumber not in accountsDictionary:
        print("\n🚫 The Provided Account NOT Found! Please Try Again with the Correct one.\n")
        return

    oldPassword = input("Enter your old password: ")

    if accountsDictionary[yourAccountNumber]["password"] != oldPassword:
        print("\n❌ Incorrect password. Please try again.\n")
        return

    newPassword = input("Enter your new password: ")
    accountsDictionary[yourAccountNumber]["password"] = newPassword
    print("\n✅ Your password has been successfully changed.\n")

def transfer_funds():
    print("\n*** Transfer Funds ***")
    fromAccount = input("Enter the Account Number you want to transfer money from: ")

    if fromAccount not in accountsDictionary:
        print("\n🚫 The Provided Account NOT Found! Please Try Again with the Correct one.\n")
        return

    toAccount = input("Enter the Account Number you want to transfer money to: ")

    if toAccount not in accountsDictionary:
        print("\n🚫 The Provided Account NOT Found! Please Try Again with the Correct one.\n")
        return

    try:
        amount = float(input("Enter the amount you want to transfer: $"))

        if amount <= 0:
            print("\n❌ Invalid amount! Please enter a positive number.\n")
            return

        if accountsDictionary[fromAccount]["totalBalance"] < amount:
            print(f"\n⚠️ Insufficient funds! You have only ${accountsDictionary[fromAccount]['totalBalance']:.2f} in your account.\n")
            return

        accountsDictionary[fromAccount]["totalBalance"] -= amount
        accountsDictionary[toAccount]["totalBalance"] += amount

        accountsDictionary[fromAccount]["OverallTransactions"].append(f"Transferred: -${amount:.2f} to Account {toAccount}")
        accountsDictionary[toAccount]["OverallTransactions"].append(f"Received: +${amount:.2f} from Account {fromAccount}")

        print(f"\n✅ Transfer successful! ${amount:.2f} has been transferred from Account #{fromAccount} to Account #{toAccount}.\n")

    except ValueError:
        print("\n⚠️ Oops! That wasn't a valid amount. Please enter a number.\n")

def login():
    print("\n*** Login to Your Account ***")
    yourAccountNumber = input("Enter Your Account Number: ")

    if yourAccountNumber not in accountsDictionary:
        print("\n🚫 The Provided Account NOT Found! Please Try Again with the Correct one.\n")
        return None

    password = input("Enter your password: ")

    if accountsDictionary[yourAccountNumber]["password"] != password:
        print("\n❌ Incorrect password. Please try again.\n")
        return None

    print(f"\n✅ Login successful! Welcome back, {accountsDictionary[yourAccountNumber]['completeName']}!\n")
    return yourAccountNumber

def simpleBankingSystem():
    print("\n" + "="*50)
    print("   🌟 Welcome to The Simple Banking System! 🌟")
    print("  💰 Your Personal Money Management System 💰")
    print("="*50 + "\n")

    while True:
        print("\n       🔑 Your Banking Portal ")
        print("\nHere are the Services We Offer to Our Valued Customers:\n")
        print("  1. 💼 Create Account (C) ")
        print("  2. 🚪 Login (L) ")
        print("  3. 💵 Deposit Money (D) ")
        print("  4. 💳 Withdraw Money (W) ")
        print("  5. 💰 Check Balance (B) ")
        print("  6. 🔍 View Transactions (T) ")
        print("  7. 🔑 Change Password (P) ")
        print("  8. 💸 Transfer Funds (F) ")
        print("  9. 🚪 Exit (E)\n")
        print("="*50 + "\n")

        userSelection = input("Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) : \n C for Create \n L for Login \n D for Deposit \n W for Withdraw \n B for Balance Check \n T for Transaction History \n P for Change Password \n F for Fund Transfer \n E for Exit.\n\n ")

        if userSelection == 'C':
            createNewAccount()
        elif userSelection == 'L':
            login()
        elif userSelection == 'D':
            depositMoneyInAcc()
        elif userSelection == 'W':
            withdraw_money()
        elif userSelection == 'B':
            check_balance()
        elif userSelection == 'T':
            view_transactions()
        elif userSelection == 'P':
            change_password()
        elif userSelection == 'F':
            transfer_funds()
        elif userSelection == 'E':
            print("🚪 Thank you for using our Banking System! Have a GOOD DAY!\n")
            break
        else:
            print("⚠️ Oops! The chosen option does not exist. Please try among the (C, D, W, B, T, P, F, E) letters.")

if __name__ == "__main__":
    simpleBankingSystem()
# Out:
# ==================================================
#    🌟 Welcome to The Simple Banking System! 🌟
#   💰 Your Personal Money Management System 💰
# ==================================================
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  C
#
# *** Create a New Account ***
#
# Enter Your Complete Name: Musfirah Fayyaz
# Select Your New Account Number: 12345
# Set a password for your account: password123
# 🎉 The Account has now been created for Musfirah Fayyaz with Account # : 12345.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  C
#
# *** Create a New Account ***
#
# Enter Your Complete Name: Ahmed Ansari
# Select Your New Account Number: 12345
# Uh-oh! The Provided Account Number Already Exists. Kindly Select a Unique One.
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  L
#
# *** Login to Your Account ***
# Enter Your Account Number: 12345
# Enter your password: password123
# ✅ Login successful! Welcome back, Musfirah Fayyaz!
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  L
#
# *** Login to Your Account ***
# Enter Your Account Number: 12345
# Enter your password: wrongpassword
# ❌ Incorrect password. Please try again.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  L
#
# *** Login to Your Account ***
# Enter Your Account Number: 99999
# 🚫 The Provided Account NOT Found! Please Try Again with the Correct one.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  D
#
# *** Deposit Money Into Your ACCOUNT ***
# Please Type Your Complete Account # Here: 12345
# Enter the amount you want to deposit in: $500
# ✅ The amount has been deposited successfully! $500.00 has been added to your account.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  D
#
# *** Deposit Money Into Your ACCOUNT ***
# Please Type Your Complete Account # Here: 12345
# Enter the amount you want to deposit in: $-100
# ❌ Invalid amount! Please enter a valid positive number.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  D
#
# *** Deposit Money Into Your ACCOUNT ***
# Please Type Your Complete Account # Here: 12345
# Enter the amount you want to deposit in: $abc
# ⚠️ Oops! That wasn't a valid amount. Please enter a number.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  W
#
# *** Withdraw Money ***
# Please Type Your Complete Account # Here: 200
# 🚫 The Provided Account NOT Found in Valid Accounts List! Please Try Again with the Correct one.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  W
#
# *** Withdraw Money ***
# Please Type Your Complete Account # Here: 1000
# 🚫 The Provided Account NOT Found in Valid Accounts List! Please Try Again with the Correct one.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  W
#
# *** Withdraw Money ***
# Please Type Your Complete Account # Here: -100
# 🚫 The Provided Account NOT Found in Valid Accounts List! Please Try Again with the Correct one.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  W
#
# *** Withdraw Money ***
# Please Type Your Complete Account # Here: abc
# 🚫 The Provided Account NOT Found in Valid Accounts List! Please Try Again with the Correct one.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  C
#
# *** Create a New Account ***
#
# Enter Your Complete Name: c
# Select Your New Account Number: 4
# Set a password for your account: p
# 🎉 The Account has now been created for c with Account # : 4.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  B
#
# *** Check Your Balance Here ***
# Please Type Your Complete Account # Here: 12345
# Your current balance is: $500.00
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  B
#
# *** Check Your Balance Here ***
# Please Type Your Complete Account # Here: 99999
# 🚫 The Provided Account NOT Found in Valid Accounts List! Please Try Again with the Correct one.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  T
#
# *** View Your Transaction History ***
# Please Type Your Complete Account # Here: 12345
# Transaction history:
# - Deposited: +$500.00
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  T
#
# *** View Your Transaction History ***
# Please Type Your Complete Account # Here: 99999
# 🚫 The Provided Account NOT Found! Please Try Again with the Correct one.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  P
#
# *** Change Your Account Password ***
# Enter Your Account Number: 12345
# Enter your old password: password123
# Enter your new password: newpassword123
# ✅ Your password has been successfully changed.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  C
#
# *** Create a New Account ***
#
# Enter Your Complete Name: musfi
# Select Your New Account Number: 44444
# Set a password for your account: ppppp
# 🎉 The Account has now been created for musfi with Account # : 44444.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  F
#
# *** Transfer Funds ***
# Enter the Account Number you want to transfer money from: 12345
# Enter the Account Number you want to transfer money to: 44444
# Enter the amount you want to transfer: $50
# ✅ Transfer successful! $50.00 has been transferred from Account #12345 to Account #44444.
#
#
#        🔑 Your Banking Portal
#
# Here are the Services We Offer to Our Valued Customers:
#
#   1. 💼 Create Account (C)
#   2. 🚪 Login (L)
#   3. 💵 Deposit Money (D)
#   4. 💳 Withdraw Money (W)
#   5. 💰 Check Balance (B)
#   6. 🔍 View Transactions (T)
#   7. 🔑 Change Password (P)
#   8. 💸 Transfer Funds (F)
#   9. 🚪 Exit (E)
#
# ==================================================
#
# Type the service option you want to avail among the (C, L, D, W, B, T, P, F, E) :
#  C for Create
#  L for Login
#  D for Deposit
#  W for Withdraw
#  B for Balance Check
#  T for Transaction History
#  P for Change Password
#  F for Fund Transfer
#  E for Exit.
#
#  E
# 🚪 Thank you for using our Banking System! Have a GOOD DAY!
